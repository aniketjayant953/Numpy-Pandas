# %%
import numpy as np
import pandas as pd

# to visualize all the column, run the below code
pd.options.display.max_columns = None
# to show all the records, use the below code
# pd.options.display.max_rows = None

# %% [markdown]
# ## Fifa Worldcup - 2022 dataset.
#
# You can find the dataset from [here](https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results).
#
# Also you can directly use an url to read the dataset by using `pd.read_csv()` method. Check the below code cell.

# %% [markdown]
# ### `Q-1:` Use the football dataset. Find out the total percentages that each team made on target. Display the result as a python dictionary where the keys are the team list and the values are the percentage values. Round off the percentage values up to 2 decimal places.
#
# *Help:*
# - First, find out how many total teams are participated in this worldcup. For that, you can use `unique()` method on the column "Team" or "Against".
# - Loop through the teams list that you have found in previous section, and then filter the dataset according to that. After filtering the dataset, find out total attempts sum and total on target sum.
# - After getting these values, find out the percentage by total on target divided by total attempts and multiply by 100. And store to a python dictionary where the key will be the team name and the values will be the percentages.
# - At the end,sort the dictionary by the values (not by the keys) and print the result.

# %% [markdown]
# **Sample Output:**
# ```bash
# {'Costa Rica': 54.55,
#  'Cameroon': 51.85,
#  'Ecuador': 48.15,
#  'Argentina': 46.99,
#  'Brazil': 45.56,
#  'England': 45.0,
#  'Portugal': 40.32,
#  'Ghana': 40.0,
#  'Netherlands': 39.02,
#  'Korea Republic': 36.73,
#  'Australia': 36.0,
#  'Mexico': 34.88,
#  'Croatia': 34.78,
#  'Germany': 34.33,
#  'France': 32.97,
#  'Spain': 32.69,
#  'Belgium': 32.35,
#  'Serbia': 32.26,
#  'Iran': 31.43,
#  'Uruguay': 31.25,
#  'United States': 31.11,
#  'Saudi Arabia': 31.03,
#  'Senegal': 30.77,
#  'Denmark': 30.56,
#  'Switzerland': 30.56,
#  'Japan': 30.23,
#  'Wales': 29.17,
#  'Qatar': 28.57,
#  'Morocco': 28.3,
#  'Tunisia': 26.67,
#  'Poland': 25.0,
#  'Canada': 17.65}
# ```

# %%
# To get the details about the dataset, please visit
# https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results

url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vT3D_x_4DS6d51LKJ7ze1sxT5WpV5uiSVOFYHLwBiGru6vFyVv5h5-83AwFjxWYiWfCDjDAaarHAV-k/pub?gid=0&single=true&output=csv"
df = pd.read_csv(url)
df.head()
# Out:
#    Sl. No  Match No.     Team      Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar      Ecuador     A     0              40
# 1       2          1  Ecuador        Qatar     A     2              46
# 2       3          2  England         Iran     B     6              69
# 3       4          2     Iran      England     B     2              20
# 4       5          3  Senegal  Netherlands     A     0              39
#
#    Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# 0                    0                     0        0               5
# 1                    2                     0        1               5
# 2                    6                     0        6              13
# 3                    2                     0        1               8
# 4                    0                     0        0              15
#
#    On Target  Off Target  Target in Penalty  Target from Outside  \
# 0          0           5                  2                    3
# 1          5           2                  4                    1
# 2          7           3                 10                    3
# 3          3           4                  6                    2
# 4          4           7                  8                    7
#
#    Left Channel  Left Inside Channel  Central Channel  Right Inside Channel  \
# 0            15                    0                3                     1
# 1             8                    7                6                     4
# 2            11                    5                2                     3
# 3             3                    0                3                     1
# 4            12                    4                2                     4
#
#    Right Channel  Receptions MD  Receptions D  Attempted Line Breaks  \
# 0              9             45             5                    159
# 1              6             55            10                    159
# 2             11             72            15                    133
# 3              1             34             1                     56
# 4             13            101            12                    143
#
#    Completed Line Breaks  Attempted Defensive Line Breaks  \
# 0                    100                                6
# 1                    103                                6
# 2                     94                                8
# 3                     19                                1
# 4                     86                                6
#
#    Completed Defensive Line Breaks  Yellow Cards  Red Cards  Fouls Against  \
# 0                                4             4          0             15
# 1                                4             2          0             15
# 2                                6             0          0              9
# 3                                1             2          0             14
# 4                                6             2          0             13
#
#    Offsides  Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0         3     453               387       10                  5        1
# 1         4     484               419       26                 10        3
# 2         2     810               733       29                  9        8
# 3         2     232               156       11                  3        0
# 4         2     391               326       22                  8        6
#
#    Free Kicks  Penalties Scored  Pts
# 0          19                 0    0
# 1          17                 1    3
# 2          16                 0    3
# 3          10                 1    0
# 4          14                 0    0

# %%
# code here
teams = df['Team'].unique()

dic = {}

for i in teams:
    group = df[df['Team'] == i][['Total Attempts','On Target']].sum()
    dic.update({i:round(group[1]/group[0]*100,2)})
    
dict(sorted(dic.items(),key = lambda x:x[1],reverse=True))
# Out:
# {'Costa Rica': 54.55,
#  'Cameroon': 51.85,
#  'Ecuador': 48.15,
#  'Argentina': 46.15,
#  'Brazil': 45.56,
#  'England': 45.0,
#  'Portugal': 40.32,
#  'Ghana': 40.0,
#  'Netherlands': 39.02,
#  'Korea Republic': 36.73,
#  'Australia': 36.0,
#  'Mexico': 34.88,
#  'France': 34.65,
#  'Germany': 34.33,
#  'Croatia': 33.73,
#  'Spain': 32.69,
#  'Belgium': 32.35,
#  'Serbia': 32.26,
#  'Iran': 31.43,
#  'Uruguay': 31.25,
#  'United States': 31.11,
#  'Saudi Arabia': 31.03,
#  'Senegal': 30.77,
#  'Denmark': 30.56,
#  'Switzerland': 30.56,
#  'Japan': 30.23,
#  'Wales': 29.17,
#  'Qatar': 28.57,
#  'Morocco': 28.33,
#  'Tunisia': 26.67,
#  'Poland': 25.0,
#  'Canada': 17.65}

# %% [markdown]
# ### `Q-2:` Find out how many times the teams are played in this Fifa Worldcup-2022. On top of this, find out the ranks of the teams.
#
# Note: The `DataFrame.rank()` method takes an optiinal parameter named `method`. This parameter takes different values, but one of them is `average` which is by-default. So, when you do the rank, you will get some 2.5 like floating values. But if you change the value as `first`, then you will get in integers but the datatype will be float. So, try with `method="first"` parameter.

# %%
# code here
df['Team'].value_counts().rank(method='first',ascending=False)
# Out:
# Morocco            1.0
# Croatia            2.0
# Argentina          3.0
# France             4.0
# England            5.0
# Brazil             6.0
# Netherlands        7.0
# Portugal           8.0
# Poland             9.0
# Japan             10.0
# Switzerland       11.0
# Australia         12.0
# Korea Republic    13.0
# United States     14.0
# Senegal           15.0
# Spain             16.0
# Cameroon          17.0
# Uruguay           18.0
# Belgium           19.0
# Ghana             20.0
# Canada            21.0
# Qatar             22.0
# Costa Rica        23.0
# Germany           24.0
# Ecuador           25.0
# Mexico            26.0
# Tunisia           27.0
# Denmark           28.0
# Saudi Arabia      29.0
# Wales             30.0
# Iran              31.0
# Serbia            32.0
# Name: Team, dtype: float64

# %% [markdown]
# ### `Q-3:` Find out these below topics:
# - The information about the Fifa worldcup dataset.
# - The description about the Fifa worldcup dataset
# - Check is there any missing values, if there is any missing values, fill that value with the average value for that particular column.
# - Drop all the duplicate rows permanently.
# - Drop the columns: "Sl No", "Match No.", "Red Cards" and "Pts" permanently.

# %%
# code here
df.info()
df.describe()
df.isnull().sum()
df.drop_duplicates(inplace=True)
df.drop(columns=["Sl. No", "Match No.", "Red Cards", "Pts"])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 128 entries, 0 to 127
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Sl. No                           128 non-null    int64
#  1   Match No.                        128 non-null    int64
#  2   Team                             128 non-null    object
#  3   Against                          128 non-null    object
#  4   Group                            128 non-null    object
#  5   Goal                             128 non-null    int64
#  6   Possession (%)                   128 non-null    int64
#  7   Inside Penalty Area              128 non-null    int64
#  8   Outside Penalty Area             128 non-null    int64
#  9   Assists                          128 non-null    int64
#  10  Total Attempts                   128 non-null    int64
#  11  On Target                        128 non-null    int64
#  12  Off Target                       128 non-null    int64
#  13  Target in Penalty                128 non-null    int64
#  14  Target from Outside              128 non-null    int64
#  15  Left Channel                     128 non-null    int64
#  16  Left Inside Channel              128 non-null    int64
#  17  Central Channel                  128 non-null    int64
#  18  Right Inside Channel             128 non-null    int64
#  19  Right Channel                    128 non-null    int64
#  20  Receptions MD                    128 non-null    int64
#  21  Receptions D                     128 non-null    int64
#  22  Attempted Line Breaks            128 non-null    int64
#  23  Completed Line Breaks            128 non-null    int64
#  24  Attempted Defensive Line Breaks  128 non-null    int64
#  25  Completed Defensive Line Breaks  128 non-null    int64
#  26  Yellow Cards                     128 non-null    int64
#  27  Red Cards                        128 non-null    int64
#  28  Fouls Against                    128 non-null    int64
#  29  Offsides                         128 non-null    int64
#  30  Passes                           128 non-null    int64
#  31  Passes Completed                 128 non-null    int64
#  32  Crosses                          128 non-null    int64
#  33  Crosses Completed                128 non-null    int64
#  34  Corners                          128 non-null    int64
#  35  Free Kicks                       128 non-null    int64
#  36  Penalties Scored                 128 non-null    int64
#  37  Pts                              128 non-null    int64
# dtypes: int64(35), object(3)
# memory usage: 39.0+ KB
#           Team      Against Group  Goal  Possession (%)  Inside Penalty Area  \
# 0        Qatar      Ecuador     A     0              40                    0
# 1      Ecuador        Qatar     A     2              46                    2
# 2      England         Iran     B     6              69                    6
# 3         Iran      England     B     2              20                    2
# 4      Senegal  Netherlands     A     0              39                    0
# ..         ...          ...   ...   ...             ...                  ...
# 123    Morocco         Fram     F     0              55                    0
# 124    Croatia      Morocco     F     2              45                    2
# 125    Morocco      Croatia     F     1              45                    1
# 126  Argentina       France     C     3              46                    3
# 127     France    Argentina     D     3              40                    3
#
#      Outside Penalty Area  Assists  Total Attempts  On Target  Off Target  \
# 0                       0        0               5          0           5
# 1                       0        1               5          5           2
# 2                       0        6              13          7           3
# 3                       0        1               8          3           4
# 4                       0        0              15          4           7
# ..                    ...      ...             ...        ...         ...
# 123                     0        0              13          1           6
# 124                     0        2              14          4           8
# 125                     0        0               7          2           5
# 126                     0        1              21          9           9
# 127                     0        1              10          5           3
#
#      Target in Penalty  Target from Outside  Left Channel  \
# 0                    2                    3            15
# 1                    4                    1             8
# 2                   10                    3            11
# 3                    6                    2             3
# 4                    8                    7            12
# ..                 ...                  ...           ...
# 123                  8                    5            10
# 124                  7                    7            20
# 125                  5                    2            13
# 126                 13                    8            13
# 127                  7                    3            15
#
#      Left Inside Channel  Central Channel  Right Inside Channel  \
# 0                      0                3                     1
# 1                      7                6                     4
# 2                      5                2                     3
# 3                      0                3                     1
# 4                      4                2                     4
# ..                   ...              ...                   ...
# 123                    4                6                     6
# 124                    8                3                     2
# 125                    1                3                     7
# 126                    6                8                     9
# 127                    7                5                     4
#
#      Right Channel  Receptions MD  Receptions D  Attempted Line Breaks  \
# 0                9             45             5                    159
# 1                6             55            10                    159
# 2               11             72            15                    133
# 3                1             34             1                     56
# 4               13            101            12                    143
# ..             ...            ...           ...                    ...
# 123             19             74            15                    141
# 124              7            106            15                    164
# 125             16             75            10                    150
# 126              9            163            28                    249
# 127             12             69             9                    179
#
#      Completed Line Breaks  Attempted Defensive Line Breaks  \
# 0                      100                                6
# 1                      103                                6
# 2                       94                                8
# 3                       19                                1
# 4                       86                                6
# ..                     ...                              ...
# 123                     95                               18
# 124                    114                               23
# 125                     97                               14
# 126                    172                               40
# 127                    107                               14
#
#      Completed Defensive Line Breaks  Yellow Cards  Fouls Against  Offsides  \
# 0                                  4             4             15         3
# 1                                  4             2             15         4
# 2                                  6             0              9         2
# 3                                  1             2             14         2
# 4                                  6             2             13         2
# ..                               ...           ...            ...       ...
# 123                               11             1             11         3
# 124                               12             0             13         2
# 125                                8             2             11         2
# 126                               24             4             26         4
# 127                                9             3             19         4
#
#      Passes  Passes Completed  Crosses  Crosses Completed  Corners  \
# 0       453               387       10                  5        1
# 1       484               419       26                 10        3
# 2       810               733       29                  9        8
# 3       232               156       11                  3        0
# 4       391               326       22                  8        6
# ..      ...               ...      ...                ...      ...
# 123     583               518       22                  1        3
# 124     491               430       21                  3        6
# 125     494               428       20                  5        3
# 126     648               544       20                  4        6
# 127     516               419       24                  3        5
#
#      Free Kicks  Penalties Scored
# 0            19                 0
# 1            17                 1
# 2            16                 0
# 3            10                 1
# 4            14                 0
# ..          ...               ...
# 123          15                 0
# 124          13                 0
# 125          15                 0
# 126          22                 5
# 127          28                 4
#
# [128 rows x 34 columns]

# %% [markdown]
# ###`Q-4:` Do these below operations:
# - Find out the rank based on the "Team" column and save the result by adding a new column named "Rank".
# - Change the datatype of this column to integer by using `np.int16`
# - Set the index of the DataFrame by using this "Rank" column permanently.
# - After that, sort the dataframe based on the "Rank" index.

# %%
# code here
df['Rank'] = df['Team'].rank(method='first')
df['Rank'] = df['Rank'].astype('int16')
df.set_index('Rank',inplace=True)
df.sort_index()
# Out:
#       Sl. No  Match No.       Team        Against Group  Goal  Possession (%)  \
# Rank
# 1          9          5  Argentina   Saudi Arabia     C     1              51
# 2         47         24  Argentina         Mexico     C     2              50
# 3         78         39  Argentina         Poland     C     2              67
# 4         99         50  Argentina      Australia     C     2              53
# 5        116         58  Argentina    Netherlands     C     2              44
# ...      ...        ...        ...            ...   ...   ...             ...
# 124       64         32    Uruguay       Portugal     H     0              35
# 125       90         45    Uruguay          Ghana     H     2              39
# 126        8          4      Wales  United States     B     1              39
# 127       33         17      Wales           Iran     B     0              51
# 128       69         35      Wales        England     B     0              33
#
#       Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# Rank
# 1                       1                     0        0              14
# 2                       1                     1        2               5
# 3                       1                     1        2              25
# 4                       2                     0        1              14
# 5                       2                     0        1              15
# ...                   ...                   ...      ...             ...
# 124                     0                     0        0              10
# 125                     2                     0        1              12
# 126                     1                     0        0               7
# 127                     0                     0        0              10
# 128                     0                     0        0               7
#
#       On Target  Off Target  Target in Penalty  Target from Outside  \
# Rank
# 1             6           6                 10                    4
# 2             2           3                  2                    3
# 3            13           8                 10                   15
# 4             5           7                 11                    3
# 5             6           8                  5                   10
# ...         ...         ...                ...                  ...
# 124           3           6                  6                    4
# 125           7           5                  7                    5
# 126           3           3                  5                    2
# 127           3           4                  5                    5
# 128           1           3                  1                    6
#
#       Left Channel  Left Inside Channel  Central Channel  \
# Rank
# 1               12                    4                5
# 2               10                    6                2
# 3               25                    8                7
# 4               15                    6               11
# 5                7                    7               13
# ...            ...                  ...              ...
# 124             13                    8                4
# 125              7                    2               13
# 126              7                    2                5
# 127             18                    3                8
# 128              7                    1                2
#
#       Right Inside Channel  Right Channel  Receptions MD  Receptions D  \
# Rank
# 1                        8             18             91            27
# 2                        4             12             89             2
# 3                       10             26            150            36
# 4                        2             17            127             8
# 5                        6             17            104             7
# ...                    ...            ...            ...           ...
# 124                      5              9             94             6
# 125                      3             17            186            14
# 126                      2              7             73             9
# 127                     11             13            101            13
# 128                      0              4             46             1
#
#       Attempted Line Breaks  Completed Line Breaks  \
# Rank
# 1                       195                    127
# 2                       150                    100
# 3                       141                    126
# 4                       181                    135
# 5                       203                    122
# ...                     ...                    ...
# 124                     150                     86
# 125                     186                    124
# 126                     174                    103
# 127                     208                    129
# 128                     104                     55
#
#       Attempted Defensive Line Breaks  Completed Defensive Line Breaks  \
# Rank
# 1                                  10                                8
# 2                                  10                                5
# 3                                  20                               16
# 4                                  16                                8
# 5                                  24                                8
# ...                               ...                              ...
# 124                                17                               11
# 125                                24                               14
# 126                                17                                8
# 127                                17                                8
# 128                                 4                                1
#
#       Yellow Cards  Red Cards  Fouls Against  Offsides  Passes  \
# Rank
# 1                0          0              7        10     593
# 2                1          0             15         2     533
# 3                1          0             11         0     862
# 4                0          0              8         4     711
# 5                8          0             18         2     603
# ...            ...        ...            ...       ...     ...
# 124              2          0             16         0     390
# 125              3          0             11         2     446
# 126              2          0             10         1     409
# 127              1          1              9         2     508
# 128              2          0             16         1     325
#
#       Passes Completed  Crosses  Crosses Completed  Corners  Free Kicks  \
# Rank
# 1                  525       36                 15        9          21
# 2                  464       14                  2        4          23
# 3                  814       22                  5        9           5
# 4                  635        6                  1        1          15
# 5                  511       16                  4        8          30
# ...                ...      ...                ...      ...         ...
# 124                306       18                  5        2          13
# 125                361       15                  4        2          20
# 126                321       15                  6        3          15
# 127                413       20                  5        2          12
# 128                261        4                  1        1          10
#
#       Penalties Scored  Pts
# Rank
# 1                    1    0
# 2                    0    3
# 3                    0    3
# 4                    0    3
# 5                    5    3
# ...                ...  ...
# 124                  0    0
# 125                  0    3
# 126                  1    1
# 127                  0    1
# 128                  0    0
#
# [128 rows x 38 columns]

# %% [markdown]
# ## Questions on Titanic dataset.
#
# You can get the dataset from [here](https://www.kaggle.com/competitions/titanic). This is the competition page on Kaggle. To download the dataset from here, I guess you have to register for the compition. So, do so and then download the dataset.
#
# Also, for now you can use this url to read the dataset like before:
# - dataset 1: https://docs.google.com/spreadsheets/d/e/2PACX-1vQjh5HzZ1N0SU7ME9ZQRzeVTaXaGsV97rU8R7eAcg53k27GTstJp9cRUOfr55go1GRRvTz1NwvyOnuh/pub?gid=1562145139&single=true&output=csv
# - dataset 2: https://docs.google.com/spreadsheets/d/e/2PACX-1vQcPvQsSC9aNFogvbUG08nu0bGHlOclGYaOlhND_LE5Ff7ZnHQ5VYzAgpyT5XNklgiT54SsNgHePsUa/pub?gid=1656109608&single=true&output=csv

# %% [markdown]
# ### `Q-5:` Do the below tasks:
# 1. With dataset 1, drop those records which only have missing values of the "Age" column permanently.
#
# 2. With the dataset 2, fill the missing values with 20 to the only "Age" column permanently.

# %%
# code here
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.head()
# test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.isnull().sum()
train.dropna(subset='Age',inplace=True)

# %%
test.isnull().sum()
test.Age.fillna(20,inplace=True)

# %% [markdown]
# ## Questions on IPL wala dataset
#
# matches dataset = https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# Code to directly use in colab
# ```
# ipl_matches = "https://docs.google.com/spreadsheets/d/e/2PACX-1vRy2DUdUbaKx_Co9F0FSnIlyS-8kp4aKv_I0-qzNeghiZHAI_hw94gKG22XTxNJHMFnFVKsO4xWOdIs/pub?gid=1655759976&single=true&output=csv"
#
# ```

# %% [markdown]
# ###`Q-6:` Make a dataframe of each team in IPL with details like - Team Name, Matches Played, Win%, Home Win%, Away Win%.
# Show sorted dataframe on Win%
#
# Replace old team name as new name before performing any tasks.
# ```
# Delhi Daredevils ->Delhi Capitals
# Kings XI Punjab -> Punjab Kings
# Rising Pune Supergiants -> Rising Pune Supergiant
# ```
#
# Note: Team1 represents Home team. Exclude not result matches.

# %%
# code here
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
#                                         Team2Players      Umpire1      Umpire2
# 0  ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...  CB Gaffaney  Nitin Menon
# 1  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...  CB Gaffaney  Nitin Menon

# %%
ipl.replace({'Delhi Daredevils' :'Delhi Capitals',
             'Kings XI Punjab' : 'Punjab Kings',
             'Rising Pune Supergiants' : 'Rising Pune Supergiant'},inplace=True)

# %%
ipl.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
ipl = ipl[ipl['WinningTeam'].notnull()]

# %%
teams = ipl['Team1'].value_counts() + ipl['Team2'].value_counts() 
teams
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                 222
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   45
# Punjab Kings                   218
# Rajasthan Royals               190
# Rising Pune Supergiant          30
# Royal Challengers Bangalore    223
# Sunrisers Hyderabad            152
# dtype: int64

# %%
matches = pd.DataFrame(teams)
matches.rename(columns={0:'Matches Played'},inplace=True)

# %%
matches['Wins'] = ipl['WinningTeam'].value_counts()
matches['Matches Played at Home'] = ipl['Team1'].value_counts()
matches['Matches Played not at Home'] = ipl['Team2'].value_counts()
matches['HomeWin'] = ipl[ipl['WinningTeam']==ipl['Team1']]['WinningTeam'].value_counts()
matches['AwayWin'] = ipl[ipl['WinningTeam']==ipl['Team2']]['WinningTeam'].value_counts()
matches['Wins%'] = matches['Wins']/matches['Matches Played'] *100
matches['HomeWin%'] = matches['HomeWin']/matches['Matches Played at Home'] * 100
matches['AwayWin%'] = matches['AwayWin']/matches['Matches Played not at Home'] * 100

# %%
matches
# Out:
#                              Matches Played  Wins  Matches Played at Home  \
# Chennai Super Kings                     208   121                     111
# Deccan Chargers                          75    29                      39
# Delhi Capitals                          222   103                     113
# Gujarat Lions                            30    13                      16
# Gujarat Titans                           16    12                       7
# Kochi Tuskers Kerala                     14     6                       7
# Kolkata Knight Riders                   223   114                     105
# Lucknow Super Giants                     15     9                       8
# Mumbai Indians                          231   131                     112
# Pune Warriors                            45    12                      23
# Punjab Kings                            218   101                     110
# Rajasthan Royals                        190    96                      89
# Rising Pune Supergiant                   30    15                      14
# Royal Challengers Bangalore             223   109                     123
# Sunrisers Hyderabad                     152    75                      69
#
#                              Matches Played not at Home  HomeWin  AwayWin  \
# Chennai Super Kings                                  97       65       56
# Deccan Chargers                                      36       13       16
# Delhi Capitals                                      109       53       50
# Gujarat Lions                                        14        5        8
# Gujarat Titans                                        9        4        8
# Kochi Tuskers Kerala                                  7        3        3
# Kolkata Knight Riders                               118       56       58
# Lucknow Super Giants                                  7        7        2
# Mumbai Indians                                      119       65       66
# Pune Warriors                                        22        6        6
# Punjab Kings                                        108       50       51
# Rajasthan Royals                                    101       49       47
# Rising Pune Supergiant                               16        7        8
# Royal Challengers Bangalore                         100       61       48
# Sunrisers Hyderabad                                  83       36       39
#
#                                  Wins%   HomeWin%   AwayWin%
# Chennai Super Kings          58.173077  58.558559  57.731959
# Deccan Chargers              38.666667  33.333333  44.444444
# Delhi Capitals               46.396396  46.902655  45.871560
# Gujarat Lions                43.333333  31.250000  57.142857
# Gujarat Titans               75.000000  57.142857  88.888889
# Kochi Tuskers Kerala         42.857143  42.857143  42.857143
# Kolkata Knight Riders        51.121076  53.333333  49.152542
# Lucknow Super Giants         60.000000  87.500000  28.571429
# Mumbai Indians               56.709957  58.035714  55.462185
# Pune Warriors                26.666667  26.086957  27.272727
# Punjab Kings                 46.330275  45.454545  47.222222
# Rajasthan Royals             50.526316  55.056180  46.534653
# Rising Pune Supergiant       50.000000  50.000000  50.000000
# Royal Challengers Bangalore  48.878924  49.593496  48.000000
# Sunrisers Hyderabad          49.342105  52.173913  46.987952

# %% [markdown]
# ###`Q-7:` Venues with most "no result" matches.

# %%
# code here
ipl[ipl.WonBy == 'NoResults']['Venue'].value_counts()
# Out:
# Series([], Name: Venue, dtype: int64)

# %% [markdown]
# ###`Q-8:` Player with most appearance in final match.
#
# `Team1Players` and `Team2Players` have all players name. It is not a list of players name instead it is str. So handle it as string.
#
# Hint: split and strip will help; Make a series of all players in final and do value counts

# %%
# code here
final = ipl[ipl['MatchNumber']=='Final']
final['all_player'] = final['Team1Players'] + final['Team2Players']
l = []
for i in final['all_player']:
    l.extend((i.replace("[",'').replace("]",' ').replace("'",'').split(',')))
l2 = []
for i in l:
    l2.append(i.strip())
all_players = pd.Series(l2)
all_players.value_counts().head()
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_6992\3257988492.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final['all_player'] = final['Team1Players'] + final['Team2Players']
# MS Dhoni     10
# SK Raina      8
# RA Jadeja     7
# DJ Bravo      7
# R Ashwin      7
# dtype: int64

# %% [markdown]
# ###`Q-9:` IPL Point Table
#
# Make a function `point_table` which take `season` as parameter and show points table in non-ascendng order of points and in ascending order of team name.
#
# For winning - 2 Ponits;
# For loosing - 0 Point
# For not result both team gets 1 points.
#
# Make dataframe which will have
# `TeamName` `MatchesPlayed` `MatchesWon` `NoResult` `Points`
# make `TeamName` as index.
#
# ```
# season parameter should be one of these->
# ['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08']
# ```

# %% [markdown]
# Output of two Top 2 in season 2022
# ```
# TeamName    MatchesPlayed	MatchesWon	NoResult	Points
#
# Gujarat Titans	    16	   12	       0	     24
# Rajasthan Royals	  17	   10	       0	     20
#
# ```

# %%
def point_table(season):
    teams = ipl.Team1.unique() 
    points = pd.DataFrame(index=teams)
    matches_played = []
    matches_won = []
    no_result = []
    for i in teams:
        matches_played.append(ipl[(ipl['Season']==season) & ((ipl['Team1'] == i) | (ipl['Team2'] == i))].shape[0])
        matches_won.append(ipl[(ipl['Season']==season) & (ipl['WinningTeam'] == i)].shape[0])
        no_result.append(ipl[((ipl['Team1'] == i) | (ipl['Team2'] == i)) & (ipl['Season']==season) & ipl['MatchNumber'].isnull()].shape[0])    
    points['Matches played'] = matches_played
    points['Matches Won'] = matches_won
    points['NoResult'] = no_result
    points['Points'] = points['Matches Won'] * 2
    points.sort_values(ascending=False,by='Points',inplace=True)
    
    return points
point_table('2022')
# Out:
#                              Matches played  Matches Won  NoResult  Points
# Gujarat Titans                           16           12         0      24
# Rajasthan Royals                         17           10         0      20
# Royal Challengers Bangalore              16            9         0      18
# Lucknow Super Giants                     15            9         0      18
# Delhi Capitals                           14            7         0      14
# Punjab Kings                             14            7         0      14
# Sunrisers Hyderabad                      14            6         0      12
# Kolkata Knight Riders                    14            6         0      12
# Chennai Super Kings                      14            4         0       8
# Mumbai Indians                           14            4         0       8
# Rising Pune Supergiant                    0            0         0       0
# Gujarat Lions                             0            0         0       0
# Pune Warriors                             0            0         0       0
# Deccan Chargers                           0            0         0       0
# Kochi Tuskers Kerala                      0            0         0       0

# %%
# code here
def matches_played(ipl, team):
    return ipl[(ipl.Team1 == team) | (ipl.Team2 == team)].shape[0]
def matches_won(ipl, team):
    return ipl[ipl.WinningTeam == team].shape[0]
def matches_no_result(ipl, team):
    return ipl[((ipl.Team1 == team) | (ipl.Team2 == team)) & (ipl.WinningTeam.isnull())].shape[0]

def point_table(season):
    df = ipl[ipl.Season == season]
    new_df = pd.DataFrame()
    new_df['Team Name'] = df.Team1.unique()
    new_df["Matches Played"] = new_df["Team Name"].apply(lambda x: matches_played(df, x))
    new_df["Matches Won"] = new_df["Team Name"].apply(lambda x: matches_won(df, x))
    new_df["No Result"] = new_df["Team Name"].apply(lambda x: matches_no_result(df, x))
    new_df["Points"] = new_df["Matches Won"]*2 + new_df["No Result"]
    new_df.sort_values("Points", ascending = False, inplace=True)
    new_df.set_index("Team Name", inplace=True)
    return new_df
point_table("2022")
# Out:
#                              Matches Played  Matches Won  No Result  Points
# Team Name
# Gujarat Titans                           16           12          0      24
# Rajasthan Royals                         17           10          0      20
# Royal Challengers Bangalore              16            9          0      18
# Lucknow Super Giants                     15            9          0      18
# Delhi Capitals                           14            7          0      14
# Punjab Kings                             14            7          0      14
# Sunrisers Hyderabad                      14            6          0      12
# Kolkata Knight Riders                    14            6          0      12
# Chennai Super Kings                      14            4          0       8
# Mumbai Indians                           14            4          0       8

# %% [markdown]
# ###`Q-10:` IPL Point Table cont.
# Extend the above IPL Point Table with an extra column as `SeasonPosition`
#
# Team below top 4 after sorting on `Points` and then on `TeamName` Will have same `SeasonPosition` as there rank. use rank function.
#
# Teams in Top four will have `SeasonPosition` as:
# ```
#     'Winner' - Team won final
#     'Runner' - Team lost Final
#     3 - Losing Team in Qualifier2
#     4 - Losing Team in Eliminator
# ```
#
# For changing value of pariticular cell use `df.at[row_index, col_label] = value`
#
# Output of two Top 2 in season 2022. Your result should have all teams.
# ```
# TeamName    MatchesPlayed	MatchesWon	NoResult	Points   SeasonPosition
#
# Gujarat Titans	    16	   12	       0	     24         Winner
# Rajasthan Royals	  17	   10	       0	     20         Runner
#
# ```
#
# Note: If you try to chnage value of view of any dataframe a warnig will be shown. To avoid it, make a copy of the dataframe you want to change in by `df.copy()`

# %%
# code here
def season_position(season):
    points = point_table(season)
    points['SeasonPosition'] = points['Points'].rank(ascending=False,method='first')
    points.sort_values(ascending=False,by='Points',inplace=True) 
    sorted_index = points.index
    labels = ['Winner','Runner','Third','Fourth']
    for i in range(4):
        points.at[sorted_index[i],'SeasonPosition'] = labels[i]
    return points


season_position('2018')
# Out:
#                              Matches Played  Matches Won  No Result  Points  \
# Team Name
# Chennai Super Kings                      16           11          0      22
# Sunrisers Hyderabad                      17           10          0      20
# Kolkata Knight Riders                    16            9          0      18
# Rajasthan Royals                         15            7          0      14
# Punjab Kings                             14            6          0      12
# Royal Challengers Bangalore              14            6          0      12
# Mumbai Indians                           14            6          0      12
# Delhi Capitals                           14            5          0      10
#
#                             SeasonPosition
# Team Name
# Chennai Super Kings                 Winner
# Sunrisers Hyderabad                 Runner
# Kolkata Knight Riders                Third
# Rajasthan Royals                    Fourth
# Punjab Kings                           5.0
# Royal Challengers Bangalore            6.0
# Mumbai Indians                         7.0
# Delhi Capitals                         8.0

# %%
def point_table_extension(season):
    df3 = point_table(season)
    df = ipl[ipl.Season == season].copy()
    df3["SeasonPosition"] = df3.Points.rank(ascending=False, method= 'first').astype('object')
    df["LoosingTeam"] = df[df.WinningTeam == df.Team1]["Team2"].append(df[df.WinningTeam == df.Team2]["Team1"])
    final = df[df["MatchNumber"] == "Final"]
    wining_team = final.WinningTeam.values[0]
    runner = final.LoosingTeam.values[0]
    df3.at[wining_team, "SeasonPosition"]="Winner"
    df3.at[runner, "SeasonPosition"]="Runner"
    q = df[df["MatchNumber"] == "Qualifier 2"]
    e = df[df["MatchNumber"] == "Eliminator"]
    third = q.LoosingTeam.values[0]
    fourth = e.LoosingTeam.values[0]
    df3.at[third, "SeasonPosition"] = "Third"
    df3.at[fourth, "SeasonPosition"] = "Fourth"
    return df3
point_table_extension("2022")
# Out:
# C:\Users\Aniket\AppData\Local\Temp\ipykernel_6992\637425392.py:5: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df["LoosingTeam"] = df[df.WinningTeam == df.Team1]["Team2"].append(df[df.WinningTeam == df.Team2]["Team1"])
#                              Matches Played  Matches Won  No Result  Points  \
# Team Name
# Gujarat Titans                           16           12          0      24
# Rajasthan Royals                         17           10          0      20
# Royal Challengers Bangalore              16            9          0      18
# Lucknow Super Giants                     15            9          0      18
# Delhi Capitals                           14            7          0      14
# Punjab Kings                             14            7          0      14
# Sunrisers Hyderabad                      14            6          0      12
# Kolkata Knight Riders                    14            6          0      12
# Chennai Super Kings                      14            4          0       8
# Mumbai Indians                           14            4          0       8
#
#                             SeasonPosition
# Team Name
# Gujarat Titans                      Winner
# Rajasthan Royals                    Runner
# Royal Challengers Bangalore          Third
# Lucknow Super Giants                Fourth
# Delhi Capitals                         5.0
# Punjab Kings                           6.0
# Sunrisers Hyderabad                    7.0
# Kolkata Knight Riders                  8.0
# Chennai Super Kings                    9.0
# Mumbai Indians                        10.0
