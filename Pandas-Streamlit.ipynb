# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('startup_funding.csv')
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
df.isna().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df.set_index('Sr No',inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy':'date',
    'Startup Name':'startup',
    'Industry Vertical':'vertical',
    'SubVertical':'subvertical',
    'City  Location':'city',
    'Investors Name':'investors',
    'InvestmentnType':'round',
    'Amount in USD':'amount'    
    
},inplace=True)

# %%
df['amount'] = df['amount'].fillna('0')
df['amount'] = df['amount'].str.replace(',','')
df['amount'] = df['amount'].str.replace('undisclosed','0')
df['amount'] = df['amount'].str.replace('unknown','0')
df['amount'] = df['amount'].str.replace('Undisclosed','0')

# %%
df = df[df['amount'].str.isdigit()]

# %%
df['amount'] = df['amount'].astype('float')

# %%
def to_inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['amount'] = df['amount'].apply(to_inr)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                        BYJU’S               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df['date'] = df['date'].str.replace('05/072018','05/07/2018')

# %%
df['date'] = pd.to_datetime(df['date'],errors='coerce')

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
df['date'].dt.year
# Out:
# Sr No
# 1       2020.0
# 2       2020.0
# 3       2020.0
# 4       2020.0
# 5       2020.0
#          ...
# 3040    2015.0
# 3041    2015.0
# 3042    2015.0
# 3043    2015.0
# 3044    2015.0
# Name: date, Length: 3029, dtype: float64

# %%
df = df.dropna(subset=['date','startup','vertical','city','investors','round','amount'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2822 entries, 1 to 2873
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2822 non-null   datetime64[ns]
#  1   startup      2822 non-null   object
#  2   vertical     2822 non-null   object
#  3   subvertical  2078 non-null   object
#  4   city         2822 non-null   object
#  5   investors    2822 non-null   object
#  6   round        2822 non-null   object
#  7   amount       2822 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 198.4+ KB

# %%
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
#  ' Accel Partners',
# ...

# %%
df[df['investors'].str.contains('500 Startups')].head()[['date','startup','vertical','city','round','amount']]
# Out:
#             date    startup           vertical       city           round  \
# Sr No
# 566   2017-10-25  SpotDraft  Consumer Internet    Gurgaon    Seed Funding
# 694   2017-12-07   Bottr.me         Technology  Bangalore    Seed Funding
# 727   2017-06-06     Ftcash  Consumer Internet     Mumbai  Private Equity
# 909   2017-04-24    Niramai         Healthcare  Bangalore    Seed Funding
# 1519  2016-07-07    Quickli          Logistics    Gurgaon  Private Equity
#
#        amount
# Sr No
# 566    4.5375
# 694    0.0000
# 727    0.0000
# 909    0.0000
# 1519   0.0000

# %%
df[df['investors'].str.contains('500 Startups')].groupby('startup')['amount'].sum().sort_values(ascending=False).head(1)
# Out:
# startup
# Kartrocket    49.5
# Name: amount, dtype: float64

# %%
df[df['investors'].str.contains('500 Startups')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='amount'>

# %%
df['year'] = df['date'].dt.year
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-09-01                     Mamaearth           E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/              FinTech
# 5     2020-02-01                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount  year
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000  2020
# ...

# %%
df[df['investors'].str.contains('500 Startups')].groupby('year')['amount'].sum().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
round(df['amount'].sum())
# Out:
# 296492

# %%
df[df['amount'] == df['amount'].max()]
# Out:
#             date           startup        vertical subvertical       city  \
# Sr No
# 61    2019-08-27  Rapido Bike Taxi  Transportation   Bike Taxi  Bengaluru
#
#                 investors     round   amount  year
# Sr No
# 61     Westbridge Capital  Series B  32175.0  2019

# %%
df.groupby('startup')['amount'].max().sort_values(ascending = False).head(1).values
# Out:
# array([32175.])

# %%
df.groupby('startup')['amount'].sum().mean()
# Out:
# 128.9655485705743

# %%
df['month'] = df['date'].dt.month
df
# Out:
#             date                       startup                    vertical  \
# Sr No
# 1     2020-09-01                        BYJU’S                      E-Tech
# 2     2020-01-13                        Shuttl              Transportation
# 3     2020-09-01                     Mamaearth                  E-commerce
# 4     2020-02-01  https://www.wealthbucket.in/                     FinTech
# 5     2020-02-01                        Fashor         Fashion and Apparel
# ...          ...                           ...                         ...
# 2869  2015-04-29                        Tracxn  Startup Analytics platform
# 2870  2015-04-29                          Dazo    Mobile Food Ordering app
# 2871  2015-04-29                      Tradelab  Financial Markets Software
# 2872  2015-04-29                        PiQube   Hiring Analytics platform
# 2873  2015-04-29               Travel Triangle   Online Travel Marketplace
#
#                                  subvertical       city  \
# ...

# %%
df.groupby(['year','month'])['startup'].count().reset_index().head()
# Out:
#    year  month  startup
# 0  2015      1       35
# 1  2015      2       14
# 2  2015      3       36
# 3  2015      4       65
# 4  2015      5       53

# %%
temp_df = df.groupby(['year','month'])['amount'].sum().reset_index()

# %%
temp_df['x_axis'] = temp_df['month'].astype(str) + '-' + temp_df['year'].astype(str)
temp_df[['amount','x_axis']]
# Out:
#          amount   x_axis
# 0   5274.637500   1-2015
# 1   1567.178250   2-2015
# 2   1910.658750   3-2015
# 3   4511.058750   4-2015
# 4   1401.427500   5-2015
# ..          ...      ...
# 58  3667.125000  12-2019
# 59   140.649250   1-2020
# 60    39.600000   2-2020
# 61  1801.460595   9-2020
# 62  1237.500000  10-2020
#
# [63 rows x 2 columns]

# %%
df.to_csv('startup_cleaned.csv',index=False)
